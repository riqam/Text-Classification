# %%
import joblib
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import copy

# %%
def load_data():
    X_train_vect = joblib.load('Test Kompas\X_train_vect.pkl')
    X_valid_vect = joblib.load('Test Kompas\X_valid_vect.pkl')
    X_test_vect = joblib.load('Test Kompas\X_test_vect.pkl')
    y_train = joblib.load('Test Kompas\y_train.pkl')
    y_valid = joblib.load('Test Kompas\y_valid.pkl')
    y_test = joblib.load('Test Kompas\y_test.pkl')

    return X_train_vect, X_valid_vect, X_test_vect, y_train, y_valid, y_test

# %%
X_train_vect, X_valid_vect, X_test_vect, y_train, y_valid, y_test = load_data()

# %%
def create_model_param():
    nb_params = {
    'alpha': [0.1, 0.5, 1.0]
    }
    
    lgr_params = {
        'penalty': ['l2'],
        'C': [0.01, 0.1],
        'max_iter': [100, 300, 500]
    }

    svc_params = {
    'C': [0.1, 1],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
    }

    # Create model params
    list_of_param = {
        'LogisticRegression': lgr_params,
        'SVC': svc_params,
        'MultinomialNB': nb_params
    }

    return list_of_param

# %%
create_model_param()
# Out:
# {'LogisticRegression': {'penalty': ['l2'],
#   'C': [0.01, 0.1],
#   'max_iter': [100, 300, 500]},
#  'SVC': {'C': [0.1, 1],
#   'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#   'gamma': ['scale', 'auto']},
#  'MultinomialNB': {'alpha': [0.1, 0.5, 1.0]}}

# %%
def create_model_object():
    # Buat model object
    lgr = LogisticRegression()
    nb = MultinomialNB()
    svc = SVC()

    # Buat list model
    list_of_model = [
        {'model_name': lgr.__class__.__name__, 'model_object': lgr},
        {'model_name': nb.__class__.__name__, 'model_object': nb},
        {'model_name': svc.__class__.__name__, 'model_object': svc}
    ]

    return list_of_model

# %%
create_model_object()
# Out:
# [{'model_name': 'LogisticRegression', 'model_object': LogisticRegression()},
#  {'model_name': 'MultinomialNB', 'model_object': MultinomialNB()},
#  {'model_name': 'SVC', 'model_object': SVC()}]

# %%
def train_model():
    # Buat list params dan object model
    list_of_param = create_model_param()
    list_of_model = create_model_object()

    # Buat dictionary kosong untuk model yg sudah dilatih
    list_of_tuned_model = {}

    # Train model
    for base_model in list_of_model:
        model_name = base_model['model_name']
        model_obj = copy.deepcopy(base_model['model_object'])
        model_param = list_of_param[model_name]

        print('Training model :', model_name)

        model = GridSearchCV(estimator = model_obj,
                             param_grid = model_param,
                             cv = 5,
                             n_jobs=1,
                             verbose=10,
                             scoring = 'accuracy')

        # Train model
        model.fit(X_train_vect, y_train)

        # Predict
        y_pred_train = model.predict(X_train_vect)
        y_pred_valid = model.predict(X_valid_vect)

        # Get score
        train_score = accuracy_score(y_train, y_pred_train)
        valid_score = accuracy_score(y_valid, y_pred_valid)

        # Append
        list_of_tuned_model[model_name] = {
            'model': model,
            'train_auc': train_score,
            'valid_auc': valid_score,
            'best_params': model.best_params_
        }
        
        print("Done training")
        print("")

    # Dump data
    joblib.dump(list_of_param, 'list_of_param.pkl')
    joblib.dump(list_of_model, 'list_of_model.pkl')
    joblib.dump(list_of_tuned_model, 'list_of_tuned_model.pkl')
   
    return list_of_param, list_of_model, list_of_tuned_model

# %%
list_of_param, list_of_model, list_of_tuned_model = train_model()
# Out:
# Training model : LogisticRegression
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START C=0.01, max_iter=100, penalty=l2............................
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# [CV 1/5; 1/6] END C=0.01, max_iter=100, penalty=l2;, score=0.322 total time=   1.1s
# [CV 2/5; 1/6] START C=0.01, max_iter=100, penalty=l2............................
# [CV 2/5; 1/6] END C=0.01, max_iter=100, penalty=l2;, score=0.312 total time=   1.2s
# [CV 3/5; 1/6] START C=0.01, max_iter=100, penalty=l2............................
# [CV 3/5; 1/6] END C=0.01, max_iter=100, penalty=l2;, score=0.317 total time=   1.2s
# [CV 4/5; 1/6] START C=0.01, max_iter=100, penalty=l2............................
# [CV 4/5; 1/6] END C=0.01, max_iter=100, penalty=l2;, score=0.342 total time=   1.1s
# [CV 5/5; 1/6] START C=0.01, max_iter=100, penalty=l2............................
# [CV 5/5; 1/6] END C=0.01, max_iter=100, penalty=l2;, score=0.361 total time=   1.1s
# [CV 1/5; 2/6] START C=0.01, max_iter=300, penalty=l2............................
# [CV 1/5; 2/6] END C=0.01, max_iter=300, penalty=l2;, score=0.322 total time=   1.2s
# [CV 2/5; 2/6] START C=0.01, max_iter=300, penalty=l2............................
# [CV 2/5; 2/6] END C=0.01, max_iter=300, penalty=l2;, score=0.312 total time=   1.3s
# [CV 3/5; 2/6] START C=0.01, max_iter=300, penalty=l2............................
# [CV 3/5; 2/6] END C=0.01, max_iter=300, penalty=l2;, score=0.317 total time=   1.1s
# [CV 4/5; 2/6] START C=0.01, max_iter=300, penalty=l2............................
# [CV 4/5; 2/6] END C=0.01, max_iter=300, penalty=l2;, score=0.342 total time=   1.1s
# [CV 5/5; 2/6] START C=0.01, max_iter=300, penalty=l2............................
# [CV 5/5; 2/6] END C=0.01, max_iter=300, penalty=l2;, score=0.361 total time=   1.0s
# [CV 1/5; 3/6] START C=0.01, max_iter=500, penalty=l2............................
# [CV 1/5; 3/6] END C=0.01, max_iter=500, penalty=l2;, score=0.322 total time=   1.1s
# [CV 2/5; 3/6] START C=0.01, max_iter=500, penalty=l2............................
# [CV 2/5; 3/6] END C=0.01, max_iter=500, penalty=l2;, score=0.312 total time=   1.2s
# [CV 3/5; 3/6] START C=0.01, max_iter=500, penalty=l2............................
# [CV 3/5; 3/6] END C=0.01, max_iter=500, penalty=l2;, score=0.317 total time=   1.1s
# [CV 4/5; 3/6] START C=0.01, max_iter=500, penalty=l2............................
# [CV 4/5; 3/6] END C=0.01, max_iter=500, penalty=l2;, score=0.342 total time=   1.0s
# [CV 5/5; 3/6] START C=0.01, max_iter=500, penalty=l2............................
# [CV 5/5; 3/6] END C=0.01, max_iter=500, penalty=l2;, score=0.361 total time=   1.1s
# [CV 1/5; 4/6] START C=0.1, max_iter=100, penalty=l2.............................
# [CV 1/5; 4/6] END C=0.1, max_iter=100, penalty=l2;, score=0.331 total time=   1.1s
# [CV 2/5; 4/6] START C=0.1, max_iter=100, penalty=l2.............................
# [CV 2/5; 4/6] END C=0.1, max_iter=100, penalty=l2;, score=0.331 total time=   1.2s
# [CV 3/5; 4/6] START C=0.1, max_iter=100, penalty=l2.............................
# [CV 3/5; 4/6] END C=0.1, max_iter=100, penalty=l2;, score=0.332 total time=   1.1s
# [CV 4/5; 4/6] START C=0.1, max_iter=100, penalty=l2.............................
# [CV 4/5; 4/6] END C=0.1, max_iter=100, penalty=l2;, score=0.357 total time=   1.0s
# [CV 5/5; 4/6] START C=0.1, max_iter=100, penalty=l2.............................
# [CV 5/5; 4/6] END C=0.1, max_iter=100, penalty=l2;, score=0.367 total time=   0.9s
# [CV 1/5; 5/6] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 1/5; 5/6] END C=0.1, max_iter=300, penalty=l2;, score=0.331 total time=   1.1s
# [CV 2/5; 5/6] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 2/5; 5/6] END C=0.1, max_iter=300, penalty=l2;, score=0.331 total time=   1.1s
# [CV 3/5; 5/6] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 3/5; 5/6] END C=0.1, max_iter=300, penalty=l2;, score=0.332 total time=   1.0s
# [CV 4/5; 5/6] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 4/5; 5/6] END C=0.1, max_iter=300, penalty=l2;, score=0.357 total time=   1.1s
# [CV 5/5; 5/6] START C=0.1, max_iter=300, penalty=l2.............................
# [CV 5/5; 5/6] END C=0.1, max_iter=300, penalty=l2;, score=0.367 total time=   0.9s
# [CV 1/5; 6/6] START C=0.1, max_iter=500, penalty=l2.............................
# [CV 1/5; 6/6] END C=0.1, max_iter=500, penalty=l2;, score=0.331 total time=   1.1s
# [CV 2/5; 6/6] START C=0.1, max_iter=500, penalty=l2.............................
# [CV 2/5; 6/6] END C=0.1, max_iter=500, penalty=l2;, score=0.331 total time=   1.2s
# [CV 3/5; 6/6] START C=0.1, max_iter=500, penalty=l2.............................
# [CV 3/5; 6/6] END C=0.1, max_iter=500, penalty=l2;, score=0.332 total time=   1.1s
# [CV 4/5; 6/6] START C=0.1, max_iter=500, penalty=l2.............................
# [CV 4/5; 6/6] END C=0.1, max_iter=500, penalty=l2;, score=0.357 total time=   1.0s
# [CV 5/5; 6/6] START C=0.1, max_iter=500, penalty=l2.............................
# [CV 5/5; 6/6] END C=0.1, max_iter=500, penalty=l2;, score=0.367 total time=   0.9s
# Done training
#
# Training model : MultinomialNB
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START alpha=0.1...................................................
# [CV 1/5; 1/3] END ....................alpha=0.1;, score=0.600 total time=   0.0s
# [CV 2/5; 1/3] START alpha=0.1...................................................
# [CV 2/5; 1/3] END ....................alpha=0.1;, score=0.597 total time=   0.0s
# [CV 3/5; 1/3] START alpha=0.1...................................................
# [CV 3/5; 1/3] END ....................alpha=0.1;, score=0.624 total time=   0.0s
# [CV 4/5; 1/3] START alpha=0.1...................................................
# [CV 4/5; 1/3] END ....................alpha=0.1;, score=0.592 total time=   0.0s
# [CV 5/5; 1/3] START alpha=0.1...................................................
# [CV 5/5; 1/3] END ....................alpha=0.1;, score=0.639 total time=   0.0s
# [CV 1/5; 2/3] START alpha=0.5...................................................
# [CV 1/5; 2/3] END ....................alpha=0.5;, score=0.487 total time=   0.0s
# [CV 2/5; 2/3] START alpha=0.5...................................................
# [CV 2/5; 2/3] END ....................alpha=0.5;, score=0.475 total time=   0.0s
# [CV 3/5; 2/3] START alpha=0.5...................................................
# [CV 3/5; 2/3] END ....................alpha=0.5;, score=0.492 total time=   0.0s
# [CV 4/5; 2/3] START alpha=0.5...................................................
# [CV 4/5; 2/3] END ....................alpha=0.5;, score=0.480 total time=   0.0s
# [CV 5/5; 2/3] START alpha=0.5...................................................
# [CV 5/5; 2/3] END ....................alpha=0.5;, score=0.492 total time=   0.0s
# [CV 1/5; 3/3] START alpha=1.0...................................................
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# [CV 1/5; 3/3] END ....................alpha=1.0;, score=0.438 total time=   0.0s
# [CV 2/5; 3/3] START alpha=1.0...................................................
# [CV 2/5; 3/3] END ....................alpha=1.0;, score=0.428 total time=   0.0s
# [CV 3/5; 3/3] START alpha=1.0...................................................
# [CV 3/5; 3/3] END ....................alpha=1.0;, score=0.423 total time=   0.0s
# [CV 4/5; 3/3] START alpha=1.0...................................................
# [CV 4/5; 3/3] END ....................alpha=1.0;, score=0.433 total time=   0.0s
# [CV 5/5; 3/3] START alpha=1.0...................................................
# [CV 5/5; 3/3] END ....................alpha=1.0;, score=0.439 total time=   0.0s
# Done training
#
# Training model : SVC
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5; 1/16] START C=0.1, gamma=scale, kernel=linear..........................
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# [CV 1/5; 1/16] END C=0.1, gamma=scale, kernel=linear;, score=0.312 total time=   3.3s
# [CV 2/5; 1/16] START C=0.1, gamma=scale, kernel=linear..........................
# [CV 2/5; 1/16] END C=0.1, gamma=scale, kernel=linear;, score=0.334 total time=   3.3s
# [CV 3/5; 1/16] START C=0.1, gamma=scale, kernel=linear..........................
# [CV 3/5; 1/16] END C=0.1, gamma=scale, kernel=linear;, score=0.301 total time=   3.3s
# [CV 4/5; 1/16] START C=0.1, gamma=scale, kernel=linear..........................
# [CV 4/5; 1/16] END C=0.1, gamma=scale, kernel=linear;, score=0.310 total time=   3.3s
# [CV 5/5; 1/16] START C=0.1, gamma=scale, kernel=linear..........................
# [CV 5/5; 1/16] END C=0.1, gamma=scale, kernel=linear;, score=0.370 total time=   3.3s
# [CV 1/5; 2/16] START C=0.1, gamma=scale, kernel=poly............................
# [CV 1/5; 2/16] END C=0.1, gamma=scale, kernel=poly;, score=0.212 total time=   4.8s
# [CV 2/5; 2/16] START C=0.1, gamma=scale, kernel=poly............................
# [CV 2/5; 2/16] END C=0.1, gamma=scale, kernel=poly;, score=0.212 total time=   4.8s
# [CV 3/5; 2/16] START C=0.1, gamma=scale, kernel=poly............................
# [CV 3/5; 2/16] END C=0.1, gamma=scale, kernel=poly;, score=0.213 total time=   4.9s
# [CV 4/5; 2/16] START C=0.1, gamma=scale, kernel=poly............................
# [CV 4/5; 2/16] END C=0.1, gamma=scale, kernel=poly;, score=0.213 total time=   4.9s
# [CV 5/5; 2/16] START C=0.1, gamma=scale, kernel=poly............................
# [CV 5/5; 2/16] END C=0.1, gamma=scale, kernel=poly;, score=0.213 total time=   4.8s
# [CV 1/5; 3/16] START C=0.1, gamma=scale, kernel=rbf.............................
# [CV 1/5; 3/16] END C=0.1, gamma=scale, kernel=rbf;, score=0.212 total time=   4.1s
# [CV 2/5; 3/16] START C=0.1, gamma=scale, kernel=rbf.............................
# [CV 2/5; 3/16] END C=0.1, gamma=scale, kernel=rbf;, score=0.212 total time=   4.1s
# [CV 3/5; 3/16] START C=0.1, gamma=scale, kernel=rbf.............................
# [CV 3/5; 3/16] END C=0.1, gamma=scale, kernel=rbf;, score=0.213 total time=   4.1s
# [CV 4/5; 3/16] START C=0.1, gamma=scale, kernel=rbf.............................
# [CV 4/5; 3/16] END C=0.1, gamma=scale, kernel=rbf;, score=0.213 total time=   4.2s
# [CV 5/5; 3/16] START C=0.1, gamma=scale, kernel=rbf.............................
# [CV 5/5; 3/16] END C=0.1, gamma=scale, kernel=rbf;, score=0.213 total time=   4.2s
# [CV 1/5; 4/16] START C=0.1, gamma=scale, kernel=sigmoid.........................
# [CV 1/5; 4/16] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.312 total time=   3.2s
# [CV 2/5; 4/16] START C=0.1, gamma=scale, kernel=sigmoid.........................
# [CV 2/5; 4/16] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.334 total time=   3.2s
# [CV 3/5; 4/16] START C=0.1, gamma=scale, kernel=sigmoid.........................
# [CV 3/5; 4/16] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.292 total time=   3.1s
# [CV 4/5; 4/16] START C=0.1, gamma=scale, kernel=sigmoid.........................
# [CV 4/5; 4/16] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.307 total time=   3.1s
# [CV 5/5; 4/16] START C=0.1, gamma=scale, kernel=sigmoid.........................
# [CV 5/5; 4/16] END C=0.1, gamma=scale, kernel=sigmoid;, score=0.370 total time=   3.2s
# [CV 1/5; 5/16] START C=0.1, gamma=auto, kernel=linear...........................
# [CV 1/5; 5/16] END C=0.1, gamma=auto, kernel=linear;, score=0.312 total time=   3.3s
# [CV 2/5; 5/16] START C=0.1, gamma=auto, kernel=linear...........................
# [CV 2/5; 5/16] END C=0.1, gamma=auto, kernel=linear;, score=0.334 total time=   3.2s
# [CV 3/5; 5/16] START C=0.1, gamma=auto, kernel=linear...........................
# [CV 3/5; 5/16] END C=0.1, gamma=auto, kernel=linear;, score=0.301 total time=   3.3s
# [CV 4/5; 5/16] START C=0.1, gamma=auto, kernel=linear...........................
# [CV 4/5; 5/16] END C=0.1, gamma=auto, kernel=linear;, score=0.310 total time=   3.3s
# [CV 5/5; 5/16] START C=0.1, gamma=auto, kernel=linear...........................
# [CV 5/5; 5/16] END C=0.1, gamma=auto, kernel=linear;, score=0.370 total time=   3.3s
# [CV 1/5; 6/16] START C=0.1, gamma=auto, kernel=poly.............................
# [CV 1/5; 6/16] END C=0.1, gamma=auto, kernel=poly;, score=0.212 total time=   1.8s
# [CV 2/5; 6/16] START C=0.1, gamma=auto, kernel=poly.............................
# [CV 2/5; 6/16] END C=0.1, gamma=auto, kernel=poly;, score=0.212 total time=   1.8s
# [CV 3/5; 6/16] START C=0.1, gamma=auto, kernel=poly.............................
# [CV 3/5; 6/16] END C=0.1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 4/5; 6/16] START C=0.1, gamma=auto, kernel=poly.............................
# [CV 4/5; 6/16] END C=0.1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 5/5; 6/16] START C=0.1, gamma=auto, kernel=poly.............................
# [CV 5/5; 6/16] END C=0.1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 1/5; 7/16] START C=0.1, gamma=auto, kernel=rbf..............................
# [CV 1/5; 7/16] END C=0.1, gamma=auto, kernel=rbf;, score=0.212 total time=   1.8s
# [CV 2/5; 7/16] START C=0.1, gamma=auto, kernel=rbf..............................
# [CV 2/5; 7/16] END C=0.1, gamma=auto, kernel=rbf;, score=0.212 total time=   1.7s
# [CV 3/5; 7/16] START C=0.1, gamma=auto, kernel=rbf..............................
# [CV 3/5; 7/16] END C=0.1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 4/5; 7/16] START C=0.1, gamma=auto, kernel=rbf..............................
# [CV 4/5; 7/16] END C=0.1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 5/5; 7/16] START C=0.1, gamma=auto, kernel=rbf..............................
# [CV 5/5; 7/16] END C=0.1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 1/5; 8/16] START C=0.1, gamma=auto, kernel=sigmoid..........................
# [CV 1/5; 8/16] END C=0.1, gamma=auto, kernel=sigmoid;, score=0.212 total time=   1.8s
# [CV 2/5; 8/16] START C=0.1, gamma=auto, kernel=sigmoid..........................
# [CV 2/5; 8/16] END C=0.1, gamma=auto, kernel=sigmoid;, score=0.212 total time=   1.8s
# [CV 3/5; 8/16] START C=0.1, gamma=auto, kernel=sigmoid..........................
# [CV 3/5; 8/16] END C=0.1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# [CV 4/5; 8/16] START C=0.1, gamma=auto, kernel=sigmoid..........................
# [CV 4/5; 8/16] END C=0.1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# [CV 5/5; 8/16] START C=0.1, gamma=auto, kernel=sigmoid..........................
# [CV 5/5; 8/16] END C=0.1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# [CV 1/5; 9/16] START C=1, gamma=scale, kernel=linear............................
# [CV 1/5; 9/16] END C=1, gamma=scale, kernel=linear;, score=0.691 total time=   3.7s
# [CV 2/5; 9/16] START C=1, gamma=scale, kernel=linear............................
# [CV 2/5; 9/16] END C=1, gamma=scale, kernel=linear;, score=0.672 total time=   3.7s
# [CV 3/5; 9/16] START C=1, gamma=scale, kernel=linear............................
# [CV 3/5; 9/16] END C=1, gamma=scale, kernel=linear;, score=0.690 total time=   3.6s
# [CV 4/5; 9/16] START C=1, gamma=scale, kernel=linear............................
# [CV 4/5; 9/16] END C=1, gamma=scale, kernel=linear;, score=0.658 total time=   3.5s
# [CV 5/5; 9/16] START C=1, gamma=scale, kernel=linear............................
# [CV 5/5; 9/16] END C=1, gamma=scale, kernel=linear;, score=0.746 total time=   3.6s
# [CV 1/5; 10/16] START C=1, gamma=scale, kernel=poly.............................
# [CV 1/5; 10/16] END C=1, gamma=scale, kernel=poly;, score=0.378 total time=   4.9s
# [CV 2/5; 10/16] START C=1, gamma=scale, kernel=poly.............................
# [CV 2/5; 10/16] END C=1, gamma=scale, kernel=poly;, score=0.362 total time=   4.8s
# [CV 3/5; 10/16] START C=1, gamma=scale, kernel=poly.............................
# [CV 3/5; 10/16] END C=1, gamma=scale, kernel=poly;, score=0.348 total time=   4.8s
# [CV 4/5; 10/16] START C=1, gamma=scale, kernel=poly.............................
# [CV 4/5; 10/16] END C=1, gamma=scale, kernel=poly;, score=0.357 total time=   4.8s
# [CV 5/5; 10/16] START C=1, gamma=scale, kernel=poly.............................
# [CV 5/5; 10/16] END C=1, gamma=scale, kernel=poly;, score=0.386 total time=   4.8s
# [CV 1/5; 11/16] START C=1, gamma=scale, kernel=rbf..............................
# [CV 1/5; 11/16] END C=1, gamma=scale, kernel=rbf;, score=0.575 total time=   4.4s
# [CV 2/5; 11/16] START C=1, gamma=scale, kernel=rbf..............................
# [CV 2/5; 11/16] END C=1, gamma=scale, kernel=rbf;, score=0.547 total time=   4.3s
# [CV 3/5; 11/16] START C=1, gamma=scale, kernel=rbf..............................
# [CV 3/5; 11/16] END C=1, gamma=scale, kernel=rbf;, score=0.545 total time=   4.4s
# [CV 4/5; 11/16] START C=1, gamma=scale, kernel=rbf..............................
# [CV 4/5; 11/16] END C=1, gamma=scale, kernel=rbf;, score=0.539 total time=   4.4s
# [CV 5/5; 11/16] START C=1, gamma=scale, kernel=rbf..............................
# [CV 5/5; 11/16] END C=1, gamma=scale, kernel=rbf;, score=0.596 total time=   4.4s
# [CV 1/5; 12/16] START C=1, gamma=scale, kernel=sigmoid..........................
# [CV 1/5; 12/16] END C=1, gamma=scale, kernel=sigmoid;, score=0.691 total time=   3.4s
# [CV 2/5; 12/16] START C=1, gamma=scale, kernel=sigmoid..........................
# [CV 2/5; 12/16] END C=1, gamma=scale, kernel=sigmoid;, score=0.675 total time=   3.3s
# [CV 3/5; 12/16] START C=1, gamma=scale, kernel=sigmoid..........................
# [CV 3/5; 12/16] END C=1, gamma=scale, kernel=sigmoid;, score=0.680 total time=   3.2s
# [CV 4/5; 12/16] START C=1, gamma=scale, kernel=sigmoid..........................
# [CV 4/5; 12/16] END C=1, gamma=scale, kernel=sigmoid;, score=0.658 total time=   3.3s
# [CV 5/5; 12/16] START C=1, gamma=scale, kernel=sigmoid..........................
# [CV 5/5; 12/16] END C=1, gamma=scale, kernel=sigmoid;, score=0.737 total time=   3.3s
# [CV 1/5; 13/16] START C=1, gamma=auto, kernel=linear............................
# [CV 1/5; 13/16] END C=1, gamma=auto, kernel=linear;, score=0.691 total time=   3.7s
# [CV 2/5; 13/16] START C=1, gamma=auto, kernel=linear............................
# [CV 2/5; 13/16] END C=1, gamma=auto, kernel=linear;, score=0.672 total time=   3.7s
# [CV 3/5; 13/16] START C=1, gamma=auto, kernel=linear............................
# [CV 3/5; 13/16] END C=1, gamma=auto, kernel=linear;, score=0.690 total time=   3.6s
# [CV 4/5; 13/16] START C=1, gamma=auto, kernel=linear............................
# [CV 4/5; 13/16] END C=1, gamma=auto, kernel=linear;, score=0.658 total time=   3.5s
# [CV 5/5; 13/16] START C=1, gamma=auto, kernel=linear............................
# [CV 5/5; 13/16] END C=1, gamma=auto, kernel=linear;, score=0.746 total time=   3.7s
# [CV 1/5; 14/16] START C=1, gamma=auto, kernel=poly..............................
# [CV 1/5; 14/16] END C=1, gamma=auto, kernel=poly;, score=0.212 total time=   1.9s
# [CV 2/5; 14/16] START C=1, gamma=auto, kernel=poly..............................
# [CV 2/5; 14/16] END C=1, gamma=auto, kernel=poly;, score=0.212 total time=   1.9s
# [CV 3/5; 14/16] START C=1, gamma=auto, kernel=poly..............................
# [CV 3/5; 14/16] END C=1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 4/5; 14/16] START C=1, gamma=auto, kernel=poly..............................
# [CV 4/5; 14/16] END C=1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 5/5; 14/16] START C=1, gamma=auto, kernel=poly..............................
# [CV 5/5; 14/16] END C=1, gamma=auto, kernel=poly;, score=0.213 total time=   1.9s
# [CV 1/5; 15/16] START C=1, gamma=auto, kernel=rbf...............................
# [CV 1/5; 15/16] END C=1, gamma=auto, kernel=rbf;, score=0.212 total time=   1.8s
# [CV 2/5; 15/16] START C=1, gamma=auto, kernel=rbf...............................
# [CV 2/5; 15/16] END C=1, gamma=auto, kernel=rbf;, score=0.212 total time=   1.8s
# [CV 3/5; 15/16] START C=1, gamma=auto, kernel=rbf...............................
# [CV 3/5; 15/16] END C=1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 4/5; 15/16] START C=1, gamma=auto, kernel=rbf...............................
# [CV 4/5; 15/16] END C=1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 5/5; 15/16] START C=1, gamma=auto, kernel=rbf...............................
# [CV 5/5; 15/16] END C=1, gamma=auto, kernel=rbf;, score=0.213 total time=   1.8s
# [CV 1/5; 16/16] START C=1, gamma=auto, kernel=sigmoid...........................
# [CV 1/5; 16/16] END C=1, gamma=auto, kernel=sigmoid;, score=0.212 total time=   1.8s
# [CV 2/5; 16/16] START C=1, gamma=auto, kernel=sigmoid...........................
# [CV 2/5; 16/16] END C=1, gamma=auto, kernel=sigmoid;, score=0.212 total time=   1.8s
# [CV 3/5; 16/16] START C=1, gamma=auto, kernel=sigmoid...........................
# [CV 3/5; 16/16] END C=1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# [CV 4/5; 16/16] START C=1, gamma=auto, kernel=sigmoid...........................
# [CV 4/5; 16/16] END C=1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# [CV 5/5; 16/16] START C=1, gamma=auto, kernel=sigmoid...........................
# [CV 5/5; 16/16] END C=1, gamma=auto, kernel=sigmoid;, score=0.213 total time=   1.8s
# Done training

# %%
def get_best_model():
    # Load tuned model
    list_of_tuned_model = joblib.load('list_of_tuned_model.pkl')

    # Get the best model
    best_model_name = None
    best_model = None
    best_performance = -99999
    best_model_param = None

    for model_name, model in list_of_tuned_model.items():
        if model['valid_auc'] > best_performance:
            best_model_name = model_name
            best_model = model['model']
            best_performance = model['valid_auc']
            best_model_param = model['best_params']

    # Dump the best model
    joblib.dump(best_model, 'best_model.pkl')

    # Print
    print('=============================================')
    print('Best model        :', best_model_name)
    print('Metric score      :', best_performance)
    print('Best model params :', best_model_param)
    print('=============================================')

    return best_model

# %%
get_best_model()
# Out:
# =============================================
# Best model        : SVC
# Metric score      : 0.7025
# Best model params : {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# =============================================
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=1,
#              param_grid={'C': [0.1, 1], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='accuracy', verbose=10)
